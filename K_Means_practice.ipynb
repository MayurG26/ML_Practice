# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
iris_dataset = pd.read_csv("iris-dataset.csv")

# %%
iris_dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
x = iris_dataset['sepal_length']
y = iris_dataset['sepal_width']
plt.scatter(x,y)

# %%
k_means = KMeans(2)
data = iris_dataset.copy()
k_means.fit(data)
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
cluster = iris_dataset.copy()
cluster["clusters"] = k_means.fit_predict(data)
plt.scatter(x,y,c=cluster["clusters"])
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn import preprocessing
x_scaled = preprocessing.scale(data)

# %%
x_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
k_means = KMeans(2)
k_means.fit(x_scaled)
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
cluster = iris_dataset.copy()
cluster["clusters"] = k_means.fit_predict(x_scaled)
plt.scatter(x,y,c=cluster["clusters"])
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
wcss = []
max_clusters = 10
for i in range(1,10):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    w = kmeans.inertia_
    wcss.append(w)
wcss
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
num_of_cluster = range(1,10)

# %%
num_of_cluster
# Out:
# range(1, 10)

# %%
plt.plot(num_of_cluster,wcss)
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %%
k_means = KMeans(2)
k_means.fit(x_scaled)
cluster1 = iris_dataset.copy()
cluster1["clusters"] = k_means.fit_predict(x_scaled)
plt.scatter(x,y,c=cluster1["clusters"])
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
k_means = KMeans(3)
k_means.fit(x_scaled)
cluster2 = iris_dataset.copy()
cluster2["clusters"] = k_means.fit_predict(x_scaled)
plt.scatter(x,y,c=cluster2["clusters"])
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
k_means = KMeans(5)
k_means.fit(x_scaled)
cluster3 = iris_dataset.copy()
cluster3["clusters"] = k_means.fit_predict(x_scaled)
plt.scatter(x,y,c=cluster3["clusters"])
# Out:
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/mayur/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
correct_data = pd.read_csv("iris-with-answers.csv")
correct_data['species'] = correct_data['species'].map({'setosa':0, 'versicolor':1 , 'virginica':2})
plt.scatter(x,y,c=correct_data["species"])

# %%
correct_data = pd.read_csv("iris-with-answers.csv")
correct_data['species'] = correct_data['species'].map({'setosa':0, 'versicolor':1 , 'virginica':2})
plt.scatter(correct_data['petal_width'],correct_data['petal_length'],c=correct_data["species"])

# %%
plt.scatter(cluster2['petal_width'],cluster2['petal_length'],c=cluster2["clusters"])
